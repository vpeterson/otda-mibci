# %% [markdown]
# # Example sample-wise adaptation using OTDA and BOTDA

# %%
import numpy as np # always need it
from numpy import unravel_index
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import ot
import scipy.io
import mne          
from mne.decoding import CSP
mne.set_log_level(verbose='warning') #to avoid info at terminal
import matplotlib.pyplot as pl
from MIOTDAfunctions import*

# %%
rango_cl=[0.1, 1, 10]
rango_e=[0.1, 1, 10]

# %% [markdown]
# ## load data at filter it

# %%
fName = 'Data/DataSession1_S1.mat'
s = scipy.io.loadmat(fName)

Data_S1=s["X"]
Labels_S1=s["y"]
Labels_S1=np.squeeze(Labels_S1)

#filterting with mne
[nt, nc, ns]=np.shape(Data_S1)
Data_S1=np.reshape(Data_S1, [nt, nc*ns])
Data_S1=mne.filter.filter_data(Data_S1, 128, 8, 30)
Data_S1=np.reshape(Data_S1, [nt,nc,ns])

fName = 'Data/DataSession2_S1.mat'
s2 = scipy.io.loadmat(fName)

Data_S2=s2["X"]
Labels_S2=s2["y"]
Labels_S2=np.squeeze(Labels_S2)

#filterting with mne
[nt, nc, ns]=np.shape(Data_S2)
Data_S2=np.reshape(Data_S2, [nt, nc*ns])
Data_S2=mne.filter.filter_data(Data_S2, 128, 8, 30)
Data_S2=np.reshape(Data_S2, [nt,nc,ns])

# %% [markdown]
# ### learn CSP+LDA from source data (Data_S1)

# %%
Xtr=Data_S1
Ytr=Labels_S1
csp = CSP(n_components=6, reg='empirical', log=True, norm_trace=False, cov_est='epoch')
#learn csp filters
Gtr=csp.fit_transform(Xtr,Ytr)
#learn lda
lda = LinearDiscriminantAnalysis()
lda.fit(Gtr,Ytr)
# Out:
# LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                            solver='svd', store_covariance=False, tol=0.0001)

# %% [markdown]
# ### first 20 trials of the new session used as transportation set

# %%
##
Labels_te=Labels_S2[20:]
##
Xval=Data_S2[0:20]
Yval=Labels_S2[0:20]
##
Gval=csp.transform(Xval)

# %% [markdown]
# #### for saving outcomes

# %%
yt_predict_cnda=[]
yt_predict_rnda=[]
yt_predict_retr1=[]
yt_predict_onetr1=[]
yt_predict_retr2=[]
yt_predict_onetr2=[]
yt_predict_retr3=[]
yt_predict_onetr3=[]
yt_predict_retr4=[]
yt_predict_onetr4=[]

# %% [markdown]
# ### select subset Gtr

# %%
# Subset selection re-training path
M=20
G_OTDAs_retr, Y_OTDAs_retr, regu_OTDAs_retr=\
SelectSubsetTraining_OTDAs(xs=Gtr, ys=Ytr, xv=Gval, yv=Yval, rango_e=rango_e, metrica="euclidean", kfold=20, M=M, trad=True)
G_OTDAs_onetr, Y_OTDAs_onetr, regu_OTDAs_onetr=\
    SelectSubsetTraining_OTDAs(xs=Gtr, ys=Ytr, xv=Gval, yv=Yval, rango_e=rango_e, metrica="euclidean", kfold=20, M=M, trad=False)
G_OTDAl1l2_retr, Y_OTDAl1l2_retr, regu_OTDAl1l2_retr=\
    SelectSubsetTraining_OTDAl1l2(xs=Gtr, ys=Ytr, xv=Gval, yv=Yval, rango_e=rango_e, rango_cl=rango_cl, metrica="euclidean", kfold=20, M=M, trad=True)
G_OTDAl1l2_onetr, Y_OTDAl1l2_onetr, regu_OTDAl1l2_onetr=\
    SelectSubsetTraining_OTDAl1l2(xs=Gtr, ys=Ytr, xv=Gval, yv=Yval, rango_e=rango_e, rango_cl=rango_cl, metrica="euclidean", kfold=20, M=M, trad=False)
G_BOTDAs_retr, Y_BOTDAs_retr, regu_BOTDAs_retr=\
    SelectSubsetTraining_BOTDAs(xs=Gtr, ys=Ytr, xv=Gval, yv=Yval, rango_e=rango_e, metrica="euclidean", kfold=20, M=M, trad=True)
G_BOTDAs_onetr, Y_BOTDAs_onetr, regu_BOTDAs_onetr=\
    SelectSubsetTraining_BOTDAs(xs=Gtr, ys=Ytr, xv=Gval, yv=Yval, rango_e=rango_e, metrica="euclidean", kfold=20, M=M, trad=False)
G_BOTDAl1l2_retr, Y_BOTDAl1l2_retr, regu_BOTDAl1l2_retr=\
    SelectSubsetTraining_BOTDAl1l2(xs=Gtr, ys=Ytr, xv=Gval, yv=Yval, rango_e=rango_e, rango_cl=rango_cl, metrica="euclidean", kfold=20, M=M, trad=True)
G_BOTDAl1l2_onetr, Y_BOTDAl1l2_onetr, regu_BOTDAl1l2_onetr=\
    SelectSubsetTraining_BOTDAl1l2(xs=Gtr, ys=Ytr, xv=Gval, yv=Yval, rango_e=rango_e, rango_cl=rango_cl, metrica="euclidean", kfold=20, M=M, trad=False)

# %%
for re in range(1,len(Labels_te)+1):
    print('Running testing trial={:1.0f}'.format(re))
    #testing trial
    Xte=Data_S2[20+(re-1):20+re]
    Xte=Xte.reshape(1, nc, ns)
    Yte=Labels_S2[20+(re-1):20+re]
    
    Xval=np.vstack((Xval, Xte))
    Yval=np.hstack((Yval, Yte))
    
    #csp estimation
    Gval=csp.transform(Xval)
    Gte=csp.transform(Xte)
    #feature computation
    Gte=csp.transform(Xte)
    
    #evaluate CNDA  
    yt_predict_cnda.append(lda.predict(Gte))

    #evaluate RNDA
    Xtr2=np.vstack((Xtr,Xval))
    Ytr2=np.hstack((Ytr, Yval))
    Xtr2=Xtr2[len(Yval):]
    Ytr2=Ytr2[len(Yval):]

    csp2 = CSP(n_components=6, reg='empirical', log=True, norm_trace=False, cov_est='epoch')
    #learn csp filters
    Gtr2=csp2.fit_transform(Xtr2,Ytr2)
    #learn lda
    lda2 = LinearDiscriminantAnalysis()
    lda2.fit(Gtr2,Ytr2)

    Gte2=csp2.transform(Xte)

    #ldatest
    yt_predict_rnda.append(lda2.predict(Gte2))

    #%% # Sinkhorn Transport
    
    Gtr_daot=G_OTDAs_retr
    Ytr_daot=Y_OTDAs_retr 
    ot_sinkhorn= ot.da.SinkhornTransport(metric="euclidean",reg_e=rango_e[regu_OTDAs_retr])
    #learn the map
    ot_sinkhorn.fit(Xs=Gtr_daot, ys=Ytr_daot, Xt=Gval)
    #apply the mapping over source data
    transp_Xs_sinkhorn = ot_sinkhorn.transform(Xs=Gtr)

    # retraining
    lda3 = LinearDiscriminantAnalysis()
    lda3.fit(transp_Xs_sinkhorn,Ytr)
    # Compute acc
    yt_predict_retr1.append(lda3.predict(Gte))
    
    # Subset selection one-training path
        
    Gtr_daot=G_OTDAs_onetr
    Ytr_daot=Y_OTDAs_onetr
    ot_sinkhorn= ot.da.SinkhornTransport(metric="euclidean",reg_e=rango_e[regu_OTDAs_onetr])
    #learn the map
    ot_sinkhorn.fit(Xs=Gtr_daot, ys=Ytr_daot, Xt=Gval)
    #apply the mapping over the current testing run
    transp_Xt_sinkhorn = ot_sinkhorn.inverse_transform(Xt=Gte)        

    # Compute accuracy transformed testing data over LDA classifier trained with source data
    yt_predict_onetr1.append(lda.predict(transp_Xt_sinkhorn))
    
    #%% # Group-Lasso Transport
  
    Gtr_daot=G_OTDAl1l2_retr
    Ytr_daot=Y_OTDAl1l2_retr
    
    ot_l1l2 = ot.da.SinkhornL1l2Transport(metric="euclidean",reg_e=rango_e[regu_OTDAl1l2_retr[0]], reg_cl=rango_cl[regu_OTDAl1l2_retr[1]])

    ot_l1l2.fit(Xs=Gtr_daot, ys=Ytr_daot, Xt=Gval)

    #transport taget samples onto source samples
    transp_Xs_l1l2=ot_l1l2.transform(Xs=Gtr)

    # retraining
    lda3 = LinearDiscriminantAnalysis()
    lda3.fit(transp_Xs_l1l2,Ytr)

    # Compute acc
    yt_predict_retr2.append(lda3.predict(Gte))
    
    # one-training path

    Gtr_daot=G_OTDAl1l2_onetr
    Ytr_daot=Y_OTDAl1l2_onetr
    
    ot_l1l2 = ot.da.SinkhornL1l2Transport(metric="euclidean",reg_e=rango_e[regu_OTDAl1l2_onetr[0]], reg_cl=rango_cl[regu_OTDAl1l2_onetr[1]])

    ot_l1l2.fit(Xs=Gtr_daot, ys=Ytr_daot, Xt=Gval)

    #transport taget samples onto source samples
    transp_Xt_l1l2=ot_l1l2.inverse_transform(Xt=Gte)        
    # Compute accuracy inverse DAOT   
    yt_predict_onetr2.append(lda.predict(transp_Xt_l1l2))
    
    #%% # Backward Sinkhorn Transport
    # re-training path
    

    Gtr_botda=G_BOTDAs_retr
    Ytr_botda=Y_BOTDAs_retr
    
    bot_s= ot.da.SinkhornTransport(metric="euclidean",reg_e=rango_e[regu_BOTDAs_retr])

    bot_s.fit(Xs=Gval, ys=Yval, Xt=Gtr_botda, yt=Ytr_botda)
    
    #transport source samples onto target source

    transp_Xs_s_backward=bot_s.inverse_transform(Xt=Gtr)

    # tradicional
    lda3 = LinearDiscriminantAnalysis()
    lda3.fit(transp_Xs_s_backward,Ytr)

    # Compute acc
    yt_predict_retr3.append(lda3.predict(Gte))
    
    # re-training path
   
    Gtr_botda=G_BOTDAs_onetr
    Ytr_botda=Y_BOTDAs_onetr
    
    bot_s = ot.da.SinkhornTransport(metric="euclidean",reg_e=rango_e[regu_BOTDAs_onetr])
    
    
    bot_s.fit(Xs=Gval, ys=Yval, Xt=Gtr_botda, yt=Ytr_botda)
    #transport testing samples
    transp_Xt_s_backward=bot_s.transform(Xs=Gte)
    # Compute accuracy one-training    
    yt_predict_onetr3.append(lda.predict(transp_Xt_s_backward))
   
    #%% # Backward Group-Lasso Transport
    
    Gtr_botda=G_BOTDAl1l2_retr
    Ytr_botda=Y_BOTDAl1l2_retr
    
    bot_l1l2 = ot.da.SinkhornL1l2Transport(metric="euclidean",reg_e=rango_e[regu_BOTDAl1l2_retr[0]], reg_cl=rango_cl[regu_BOTDAl1l2_retr[1]])

    bot_l1l2.fit(Xs=Gval, ys=Yval, Xt=Gtr_botda, yt=Ytr_botda)
    
    #transport source samples onto target source

    transp_Xs_l1l2_backward=bot_l1l2.inverse_transform(Xt=Gtr)

    # tradicional
    lda3 = LinearDiscriminantAnalysis()
    lda3.fit(transp_Xs_l1l2_backward,Ytr)

    # Compute acc
    yt_predict_retr4.append(lda3.predict(Gte))
    
    # Subset selection trad (re-training path)
   
    Gtr_botda=G_BOTDAl1l2_onetr
    Ytr_botda=Y_BOTDAl1l2_onetr
    
    bot_l1l2 = ot.da.SinkhornL1l2Transport(metric="euclidean",reg_e=rango_e[regu_BOTDAl1l2_onetr[0]], reg_cl=rango_cl[regu_BOTDAl1l2_onetr[1]])
        
    bot_l1l2.fit(Xs=Gval, ys=Yval, Xt=Gtr_botda, yt=Ytr_botda)
    #transport testing samples
    transp_Xt_l1l2_backward=bot_l1l2.transform(Xs=Gte)
    # Compute accuracy one-training    
    yt_predict_onetr4.append(lda.predict(transp_Xt_l1l2_backward))
# Out:
# Running testing trial=1
# Running testing trial=2
# Running testing trial=3
# Running testing trial=4
# Running testing trial=5
# Running testing trial=6
# Running testing trial=7
# Running testing trial=8
# Running testing trial=9
# Running testing trial=10
# Running testing trial=11
# Running testing trial=12
# Running testing trial=13
# Running testing trial=14
# Running testing trial=15
# Running testing trial=16
# Running testing trial=17
# Running testing trial=18
# Running testing trial=19
# Running testing trial=20
# Running testing trial=21
# Running testing trial=22
# Running testing trial=23
# Running testing trial=24
# Running testing trial=25
# Running testing trial=26
# Running testing trial=27
# Running testing trial=28
# Running testing trial=29
# Running testing trial=30
# Running testing trial=31
# Running testing trial=32
# Running testing trial=33
# Running testing trial=34
# Running testing trial=35
# Running testing trial=36
# Running testing trial=37
# Running testing trial=38
# Running testing trial=39
# Running testing trial=40
# Running testing trial=41
# Running testing trial=42
# Running testing trial=43
# Running testing trial=44
# Running testing trial=45
# Running testing trial=46
# Running testing trial=47
# Running testing trial=48
# Running testing trial=49
# Running testing trial=50
# Running testing trial=51
# Running testing trial=52
# Running testing trial=53
# Running testing trial=54
# Running testing trial=55
# Running testing trial=56
# Running testing trial=57
# Running testing trial=58
# Running testing trial=59
# Running testing trial=60
# Running testing trial=61
# Running testing trial=62
# Running testing trial=63
# Running testing trial=64
# Running testing trial=65
# Running testing trial=66
# Running testing trial=67
# Running testing trial=68
# Running testing trial=69
# Running testing trial=70
# Running testing trial=71
# Running testing trial=72
# Running testing trial=73
# Running testing trial=74
# Running testing trial=75
# Running testing trial=76
# Running testing trial=77
# Running testing trial=78
# Running testing trial=79
# Running testing trial=80
# Running testing trial=81
# Running testing trial=82
# Running testing trial=83
# Running testing trial=84
# Running testing trial=85
# Running testing trial=86
# Running testing trial=87
# Running testing trial=88
# Running testing trial=89
# Running testing trial=90
# Running testing trial=91
# Running testing trial=92
# Running testing trial=93
# Running testing trial=94
# Running testing trial=95
# Running testing trial=96
# Running testing trial=97
# Running testing trial=98
# Running testing trial=99
# Running testing trial=100
# Running testing trial=101
# Running testing trial=102
# Running testing trial=103
# Running testing trial=104
# Running testing trial=105
# Running testing trial=106
# Running testing trial=107
# Running testing trial=108
# Running testing trial=109
# Running testing trial=110
# Running testing trial=111
# Running testing trial=112
# Running testing trial=113
# Running testing trial=114
# Running testing trial=115
# Running testing trial=116
# Running testing trial=117
# Running testing trial=118
# Running testing trial=119
# Running testing trial=120
# Running testing trial=121
# Running testing trial=122
# Running testing trial=123
# Running testing trial=124
# Running testing trial=125
# Running testing trial=126
# Running testing trial=127
# Running testing trial=128
# Running testing trial=129
# Running testing trial=130
# Running testing trial=131
# Running testing trial=132
# Running testing trial=133
# Running testing trial=134
# Running testing trial=135
# Running testing trial=136
# Running testing trial=137
# Running testing trial=138
# Running testing trial=139
# Running testing trial=140

# %%
# compute accuracy 
yt_predict_onetr4=np.squeeze(np.asarray(yt_predict_onetr4))
yt_predict_onetr3=np.squeeze(np.asarray(yt_predict_onetr3))
yt_predict_onetr2=np.squeeze(np.asarray(yt_predict_onetr2))
yt_predict_onetr1=np.squeeze(np.asarray(yt_predict_onetr1))
yt_predict_retr4=np.squeeze(np.asarray(yt_predict_retr4))
yt_predict_retr3=np.squeeze(np.asarray(yt_predict_retr3))
yt_predict_retr2=np.squeeze(np.asarray(yt_predict_retr2))
yt_predict_retr1=np.squeeze(np.asarray(yt_predict_retr1))
yt_predict_cnda=np.squeeze(np.asarray(yt_predict_cnda))
yt_predict_rnda=np.squeeze(np.asarray(yt_predict_rnda))

acc_botdal1l2_retr=accuracy_score(Labels_te, yt_predict_retr4)
acc_botdal1l2_onetr=accuracy_score(Labels_te, yt_predict_onetr4)
acc_botdas_retr=accuracy_score(Labels_te, yt_predict_retr3)
acc_botdas_onetr=accuracy_score(Labels_te, yt_predict_onetr3)
acc_otdal1l2_retr=accuracy_score(Labels_te, yt_predict_retr2)
acc_otdal1l2_onetr=accuracy_score(Labels_te, yt_predict_onetr2)
acc_otdas_retr=accuracy_score(Labels_te, yt_predict_retr1)
acc_otdas_onetr=accuracy_score(Labels_te, yt_predict_onetr1)
acc_cnda=accuracy_score(Labels_te, yt_predict_cnda)
acc_rnda=accuracy_score(Labels_te, yt_predict_rnda)

#print accuracy
acc={}
acc["cnda"]=acc_cnda
acc["rnda"]=acc_rnda
acc["otdas_retr"]=acc_otdas_retr
acc["otdas_onetr"]=acc_otdas_onetr
acc["otdal1l2_retr"]=acc_otdal1l2_retr
acc["otdal1l2_onetr"]=acc_otdal1l2_onetr
acc["botdas_retr"]=acc_botdas_retr
acc["botdas_onetr"]=acc_botdas_onetr
acc["botdal1l2_retr"]=acc_botdal1l2_retr
acc["botdal1l2_onetr"]=acc_botdal1l2_onetr
    
print(acc)
# Out:
# {'cnda': 0.7785714285714286, 'rnda': 0.85, 'otdas_retr': 0.7571428571428571, 'otdas_onetr': 0.7, 'otdal1l2_retr': 0.7214285714285714, 'otdal1l2_onetr': 0.6357142857142857, 'botdas_retr': 0.7785714285714286, 'botdas_onetr': 0.9428571428571428, 'botdal1l2_retr': 0.75, 'botdal1l2_onetr': 1.0}
